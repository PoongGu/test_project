# %% [markdown]
# <a href="https://colab.research.google.com/github/PoongGu/test_project/blob/main/04_Keras_API%EB%A5%BC_%ED%99%9C%EC%9A%A9%ED%95%9C_%EC%9E%90%EB%8F%99%EC%B0%A8_%EC%97%B0%EB%B9%84_%EC%98%88%EC%B8%A1_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DNN(MLP) 모델을 이용한 자동차 연비 데이터 셋 회귀 분석

# %%
import matplotlib.pyplot as plt
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers, models

# %%
print(tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# ### Step 1-1. Inptu tensor 와 Target tensor 준비(훈련데이터)
# * 자동차 연비 데이터셋 파일 down

# %%
auto_mpg_dataset_url = "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
dataset_path = tf.keras.utils.get_file("/content/auto-mpg.data", auto_mpg_dataset_url)
dataset_path
# Out:
# Downloading data from http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data
# 32768/30286 [================================] - 0s 2us/step
# 40960/30286 [========================================] - 0s 1us/step
# '/content/auto-mpg.data'

# %% [markdown]
# *  데이터 셋 파일을 읽어 Dataframe 객체 생성

# %%
# 자동차 연비 데이터 셋의 컬럼명
column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(dataset_path, names=column_names,
                          na_values='?', comment='\t',
                          sep=" ", skipinitialspace=True)

dataset = raw_dataset.copy()
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [398 rows x 8 columns]

# %% [markdown]
# ### Step 1-2. 입력 데이터의 전처리
# * 데이터 셋 내의 NaN 값 제거

# %%
# 데이터 셋 내의 Nan 값 체크
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
# 데이터 셋 내 의 Nan 값 제거
dataset = dataset.dropna()

# %%
len(dataset)
# Out:
# 392

# %%
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %% [markdown]
# * 데이터셋 에서 20% 선택하여 test 데이터 셋으로 분할

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0) # 테스트 데이터셋 고정
test_dataset = dataset.drop(train_dataset.index)

# %%
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 314
# 78

# %% [markdown]
# * 표준화를 통한 Input tensor의 전처리

# %%
# 데이터 전처리를 위한 통계정보 생성
train_stats = train_dataset.describe()

# %%
train_stats
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  314.000000  314.000000    314.000000  314.000000   314.000000
# mean    23.310510    5.477707    195.318471  104.869427  2990.251592
# std      7.728652    1.699788    104.331589   38.096214   843.898596
# min     10.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     17.000000    4.000000    105.500000   76.250000  2256.500000
# 50%     22.000000    4.000000    151.000000   94.500000  2822.500000
# 75%     28.950000    8.000000    265.750000  128.000000  3608.000000
# max     46.600000    8.000000    455.000000  225.000000  5140.000000
#
#        Acceleration  Model Year      Origin
# count    314.000000  314.000000  314.000000
# mean      15.559236   75.898089    1.573248
# std        2.789230    3.675642    0.800988
# min        8.000000   70.000000    1.000000
# 25%       13.800000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.200000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
# 정답 데이터(MPG-연비) 제거
train_stats.pop('MPG')
# Out:
# count    314.000000
# mean      23.310510
# std        7.728652
# min       10.000000
# 25%       17.000000
# 50%       22.000000
# 75%       28.950000
# max       46.600000
# Name: MPG, dtype: float64

# %%
train_stats
# Out:
#         Cylinders  Displacement  Horsepower       Weight  Acceleration  \
# count  314.000000    314.000000  314.000000   314.000000    314.000000
# mean     5.477707    195.318471  104.869427  2990.251592     15.559236
# std      1.699788    104.331589   38.096214   843.898596      2.789230
# min      3.000000     68.000000   46.000000  1649.000000      8.000000
# 25%      4.000000    105.500000   76.250000  2256.500000     13.800000
# 50%      4.000000    151.000000   94.500000  2822.500000     15.500000
# 75%      8.000000    265.750000  128.000000  3608.000000     17.200000
# max      8.000000    455.000000  225.000000  5140.000000     24.800000
#
#        Model Year      Origin
# count  314.000000  314.000000
# mean    75.898089    1.573248
# std      3.675642    0.800988
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# 각 특성 별 통계정보를 가공하기 쉽도록 matrix 전치
train_stats = train_stats.transpose()

# %%
train_stats
# Out:
#               count         mean         std  ...     50%      75%     max
# Cylinders     314.0     5.477707    1.699788  ...     4.0     8.00     8.0
# Displacement  314.0   195.318471  104.331589  ...   151.0   265.75   455.0
# Horsepower    314.0   104.869427   38.096214  ...    94.5   128.00   225.0
# Weight        314.0  2990.251592  843.898596  ...  2822.5  3608.00  5140.0
# Acceleration  314.0    15.559236    2.789230  ...    15.5    17.20    24.8
# Model Year    314.0    75.898089    3.675642  ...    76.0    79.00    82.0
# Origin        314.0     1.573248    0.800988  ...     1.0     2.00     3.0
#
# [7 rows x 8 columns]

# %%
# Target tensor 를 위한 연비 값(MPG - Miles Per Gallon) 추출
train_labels = train_dataset.pop('MPG')
test_labels = test_dataset.pop('MPG')

# %%
train_dataset
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year  \
# 146          4          90.0        75.0  2125.0          14.5          74
# 282          4         140.0        88.0  2890.0          17.3          79
# 69           8         350.0       160.0  4456.0          13.5          72
# 378          4         105.0        63.0  2125.0          14.7          82
# 331          4          97.0        67.0  2145.0          18.0          80
# ..         ...           ...         ...     ...           ...         ...
# 281          6         200.0        85.0  2990.0          18.2          79
# 229          8         400.0       180.0  4220.0          11.1          77
# 150          4         108.0        93.0  2391.0          15.5          74
# 145          4          83.0        61.0  2003.0          19.0          74
# 182          4         107.0        86.0  2464.0          15.5          76
#
#      Origin
# 146       1
# 282       1
# 69        1
# 378       1
# 331       3
# ..      ...
# 281       1
# 229       1
# 150       3
# 145       3
# 182       2
#
# [314 rows x 7 columns]

# %%
# Input tensor의 표준화(평균 :0/ 표준편차 :1) 함수 정의
def norm(x):
  normed_data = (x - train_stats['mean']) / train_stats['std']
  return normed_data

# %%
# Input tensor 의 특성 정보 표준화 처리 수행
train_dataset = norm(train_dataset)
test_dataset = norm(test_dataset)

# %%
train_dataset.describe()
# Out:
#           Cylinders  Displacement    Horsepower        Weight  Acceleration  \
# count  3.140000e+02  3.140000e+02  3.140000e+02  3.140000e+02  3.140000e+02
# mean   1.824443e-16  8.627211e-17 -9.900078e-18 -8.485781e-17 -5.148041e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.457657e+00 -1.220325e+00 -1.545283e+00 -1.589352e+00 -2.710152e+00
# 25%   -8.693480e-01 -8.608943e-01 -7.512407e-01 -8.694784e-01 -6.307245e-01
# 50%   -8.693480e-01 -4.247848e-01 -2.721905e-01 -1.987817e-01 -2.123729e-02
# 75%    1.483887e+00  6.750739e-01  6.071620e-01  7.320173e-01  5.882500e-01
# max    1.483887e+00  2.489002e+00  3.153347e+00  2.547401e+00  3.313017e+00
#
#          Model Year        Origin
# count  3.140000e+02  3.140000e+02
# mean   9.772791e-16 -9.617219e-17
# std    1.000000e+00  1.000000e+00
# min   -1.604642e+00 -7.156763e-01
# 25%   -7.884578e-01 -7.156763e-01
# 50%    2.772599e-02 -7.156763e-01
# 75%    8.439098e-01  5.327813e-01
# max    1.660094e+00  1.781239e+00

# %% [markdown]
# ### Step2. DNN(MLP) 모델 디자인

# %%
# hidden layer : 2개[64, 32], activation : relu
model = models.Sequential()
model.add(layers.Dense(units=64, activation='relu', input_shape=(len(train_dataset.keys()),)))
model.add(layers.Dense(units=32, activation='relu'))
model.add(layers.Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                512
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Step 3. 모델의 학습 정보 설정

# %%
# loss : mean square error/ optimizer : rmsprop/ metric : mean absolute error
model.compile(loss='mse',
              optimizer='rmsprop',
              metrics=['mae'])

# %% [markdown]
# ### Step 4. 모델에 input, target 데이터 연결 후 학습

# %%
# batch size : 16, epochs : 100, validation data set percent : 20%
history = model.fit(
    x=train_dataset, y=train_labels,
    batch_size=16,
    epochs=100,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 3s 14ms/step - loss: 568.2410 - mae: 22.6320 - val_loss: 554.9923 - val_mae: 22.3086
# Epoch 2/100
# 16/16 [==============================] - 0s 4ms/step - loss: 507.1169 - mae: 21.2602 - val_loss: 488.1904 - val_mae: 20.7669
# Epoch 3/100
# 16/16 [==============================] - 0s 4ms/step - loss: 441.6513 - mae: 19.6872 - val_loss: 410.6205 - val_mae: 18.8508
# Epoch 4/100
# 16/16 [==============================] - 0s 4ms/step - loss: 364.1386 - mae: 17.6700 - val_loss: 321.8901 - val_mae: 16.3755
# Epoch 5/100
# 16/16 [==============================] - 0s 4ms/step - loss: 279.6520 - mae: 15.1950 - val_loss: 231.7843 - val_mae: 13.5734
# Epoch 6/100
# 16/16 [==============================] - 0s 5ms/step - loss: 196.7688 - mae: 12.5262 - val_loss: 151.3983 - val_mae: 10.8228
# Epoch 7/100
# 16/16 [==============================] - 0s 4ms/step - loss: 126.8351 - mae: 9.8048 - val_loss: 90.8012 - val_mae: 8.2082
# Epoch 8/100
# 16/16 [==============================] - 0s 4ms/step - loss: 77.9371 - mae: 7.3353 - val_loss: 57.7236 - val_mae: 6.5690
# Epoch 9/100
# 16/16 [==============================] - 0s 4ms/step - loss: 52.4133 - mae: 5.8043 - val_loss: 45.7493 - val_mae: 5.7408
# Epoch 10/100
# 16/16 [==============================] - 0s 4ms/step - loss: 41.1338 - mae: 5.1855 - val_loss: 39.1241 - val_mae: 5.2135
# Epoch 11/100
# 16/16 [==============================] - 0s 4ms/step - loss: 34.1722 - mae: 4.6977 - val_loss: 32.9380 - val_mae: 4.6750
# Epoch 12/100
# 16/16 [==============================] - 0s 4ms/step - loss: 28.6102 - mae: 4.2761 - val_loss: 27.8049 - val_mae: 4.2312
# Epoch 13/100
# 16/16 [==============================] - 0s 5ms/step - loss: 24.1014 - mae: 3.8997 - val_loss: 23.6503 - val_mae: 3.8413
# Epoch 14/100
# 16/16 [==============================] - 0s 5ms/step - loss: 20.8622 - mae: 3.6077 - val_loss: 20.3218 - val_mae: 3.5958
# Epoch 15/100
# 16/16 [==============================] - 0s 5ms/step - loss: 18.2471 - mae: 3.3231 - val_loss: 17.6688 - val_mae: 3.3385
# Epoch 16/100
# 16/16 [==============================] - 0s 4ms/step - loss: 16.4606 - mae: 3.1285 - val_loss: 16.1280 - val_mae: 3.1261
# Epoch 17/100
# 16/16 [==============================] - 0s 5ms/step - loss: 14.9256 - mae: 2.9822 - val_loss: 14.0638 - val_mae: 2.9729
# Epoch 18/100
# 16/16 [==============================] - 0s 4ms/step - loss: 13.6673 - mae: 2.7864 - val_loss: 13.2952 - val_mae: 2.8371
# Epoch 19/100
# 16/16 [==============================] - 0s 5ms/step - loss: 12.8067 - mae: 2.6605 - val_loss: 12.3006 - val_mae: 2.7545
# Epoch 20/100
# 16/16 [==============================] - 0s 4ms/step - loss: 11.9078 - mae: 2.5517 - val_loss: 11.3840 - val_mae: 2.6482
# Epoch 21/100
# 16/16 [==============================] - 0s 4ms/step - loss: 11.4057 - mae: 2.5043 - val_loss: 10.9791 - val_mae: 2.6482
# Epoch 22/100
# 16/16 [==============================] - 0s 4ms/step - loss: 10.9090 - mae: 2.3845 - val_loss: 10.7568 - val_mae: 2.5431
# Epoch 23/100
# 16/16 [==============================] - 0s 4ms/step - loss: 10.4134 - mae: 2.3366 - val_loss: 10.5287 - val_mae: 2.4774
# Epoch 24/100
# 16/16 [==============================] - 0s 4ms/step - loss: 10.0973 - mae: 2.3028 - val_loss: 10.2743 - val_mae: 2.4212
# Epoch 25/100
# 16/16 [==============================] - 0s 4ms/step - loss: 9.8256 - mae: 2.2485 - val_loss: 9.9297 - val_mae: 2.4314
# Epoch 26/100
# 16/16 [==============================] - 0s 4ms/step - loss: 9.6377 - mae: 2.2109 - val_loss: 9.9831 - val_mae: 2.4520
# Epoch 27/100
# 16/16 [==============================] - 0s 5ms/step - loss: 9.4121 - mae: 2.1740 - val_loss: 9.7586 - val_mae: 2.3663
# Epoch 28/100
# 16/16 [==============================] - 0s 5ms/step - loss: 9.1226 - mae: 2.1320 - val_loss: 9.5830 - val_mae: 2.3388
# Epoch 29/100
# 16/16 [==============================] - 0s 5ms/step - loss: 8.9151 - mae: 2.1418 - val_loss: 9.7081 - val_mae: 2.3727
# Epoch 30/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.8558 - mae: 2.1284 - val_loss: 9.9186 - val_mae: 2.3291
# Epoch 31/100
# 16/16 [==============================] - 0s 5ms/step - loss: 8.7182 - mae: 2.1035 - val_loss: 9.5223 - val_mae: 2.3691
# Epoch 32/100
# 16/16 [==============================] - 0s 5ms/step - loss: 8.3913 - mae: 2.0620 - val_loss: 9.4461 - val_mae: 2.3825
# Epoch 33/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.4153 - mae: 2.0717 - val_loss: 9.4692 - val_mae: 2.3348
# Epoch 34/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.2322 - mae: 2.0377 - val_loss: 9.6206 - val_mae: 2.4240
# Epoch 35/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.2116 - mae: 2.0317 - val_loss: 9.3346 - val_mae: 2.2586
# Epoch 36/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.8191 - mae: 2.0259 - val_loss: 9.1671 - val_mae: 2.3152
# Epoch 37/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.8761 - mae: 1.9908 - val_loss: 9.1860 - val_mae: 2.3287
# Epoch 38/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.8768 - mae: 1.9847 - val_loss: 9.2278 - val_mae: 2.2599
# Epoch 39/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.7443 - mae: 1.9888 - val_loss: 9.0967 - val_mae: 2.2654
# Epoch 40/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.7843 - mae: 1.9787 - val_loss: 9.1391 - val_mae: 2.2488
# Epoch 41/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.6049 - mae: 1.9728 - val_loss: 9.1447 - val_mae: 2.2919
# Epoch 42/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.5651 - mae: 1.9479 - val_loss: 9.0622 - val_mae: 2.2967
# Epoch 43/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.4943 - mae: 1.9374 - val_loss: 8.7720 - val_mae: 2.2374
# Epoch 44/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.2148 - mae: 1.9133 - val_loss: 9.0637 - val_mae: 2.1739
# Epoch 45/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.3215 - mae: 1.9134 - val_loss: 8.7513 - val_mae: 2.2662
# Epoch 46/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.3819 - mae: 1.9232 - val_loss: 8.7208 - val_mae: 2.2731
# Epoch 47/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.2550 - mae: 1.8908 - val_loss: 8.6764 - val_mae: 2.2231
# Epoch 48/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.0622 - mae: 1.8972 - val_loss: 8.8839 - val_mae: 2.2994
# Epoch 49/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.0697 - mae: 1.8948 - val_loss: 8.6767 - val_mae: 2.2272
# Epoch 50/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.0192 - mae: 1.8758 - val_loss: 8.5778 - val_mae: 2.2138
# Epoch 51/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.0002 - mae: 1.8684 - val_loss: 8.8898 - val_mae: 2.2583
# Epoch 52/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9717 - mae: 1.8400 - val_loss: 8.6039 - val_mae: 2.2000
# Epoch 53/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.8915 - mae: 1.8513 - val_loss: 8.5133 - val_mae: 2.1685
# Epoch 54/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.9744 - mae: 1.8676 - val_loss: 8.4326 - val_mae: 2.1870
# Epoch 55/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.8010 - mae: 1.8545 - val_loss: 9.1317 - val_mae: 2.3677
# Epoch 56/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.8583 - mae: 1.8383 - val_loss: 9.0734 - val_mae: 2.3423
# Epoch 57/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.7966 - mae: 1.8250 - val_loss: 8.3926 - val_mae: 2.1976
# Epoch 58/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.7370 - mae: 1.8316 - val_loss: 8.9677 - val_mae: 2.3406
# Epoch 59/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.8726 - mae: 1.8269 - val_loss: 8.5240 - val_mae: 2.2280
# Epoch 60/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.7332 - mae: 1.8191 - val_loss: 8.4789 - val_mae: 2.1207
# Epoch 61/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.6599 - mae: 1.8329 - val_loss: 8.6859 - val_mae: 2.2486
# Epoch 62/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.8274 - mae: 1.8256 - val_loss: 8.2596 - val_mae: 2.1565
# Epoch 63/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6121 - mae: 1.8057 - val_loss: 8.6208 - val_mae: 2.2171
# Epoch 64/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6290 - mae: 1.7885 - val_loss: 8.5142 - val_mae: 2.1483
# Epoch 65/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4459 - mae: 1.7722 - val_loss: 8.9567 - val_mae: 2.1458
# Epoch 66/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6795 - mae: 1.8247 - val_loss: 8.3905 - val_mae: 2.2208
# Epoch 67/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.7157 - mae: 1.8095 - val_loss: 8.2738 - val_mae: 2.1633
# Epoch 68/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5927 - mae: 1.7895 - val_loss: 8.1633 - val_mae: 2.1152
# Epoch 69/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5467 - mae: 1.7635 - val_loss: 8.1832 - val_mae: 2.1426
# Epoch 70/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5241 - mae: 1.7713 - val_loss: 8.3991 - val_mae: 2.2213
# Epoch 71/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4333 - mae: 1.7644 - val_loss: 8.1892 - val_mae: 2.1349
# Epoch 72/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4697 - mae: 1.7799 - val_loss: 8.1622 - val_mae: 2.1639
# Epoch 73/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4896 - mae: 1.7501 - val_loss: 8.3295 - val_mae: 2.1785
# Epoch 74/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3846 - mae: 1.7782 - val_loss: 8.1732 - val_mae: 2.1402
# Epoch 75/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3423 - mae: 1.7392 - val_loss: 8.4666 - val_mae: 2.2353
# Epoch 76/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2903 - mae: 1.7609 - val_loss: 8.3925 - val_mae: 2.2062
# Epoch 77/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2714 - mae: 1.7357 - val_loss: 8.2049 - val_mae: 2.1065
# Epoch 78/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4578 - mae: 1.7613 - val_loss: 8.2031 - val_mae: 2.1121
# Epoch 79/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4541 - mae: 1.7633 - val_loss: 8.3755 - val_mae: 2.1992
# Epoch 80/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3707 - mae: 1.7041 - val_loss: 8.2473 - val_mae: 2.0893
# Epoch 81/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.2138 - mae: 1.7160 - val_loss: 8.0878 - val_mae: 2.0956
# Epoch 82/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3052 - mae: 1.7255 - val_loss: 8.2028 - val_mae: 2.1596
# Epoch 83/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.2350 - mae: 1.7439 - val_loss: 8.2168 - val_mae: 2.1160
# Epoch 84/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.2382 - mae: 1.7278 - val_loss: 8.2226 - val_mae: 2.1729
# Epoch 85/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0819 - mae: 1.6920 - val_loss: 8.0548 - val_mae: 2.0690
# Epoch 86/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3109 - mae: 1.7377 - val_loss: 8.0763 - val_mae: 2.1357
# Epoch 87/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.0998 - mae: 1.6941 - val_loss: 7.8979 - val_mae: 2.0795
# Epoch 88/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.1278 - mae: 1.7121 - val_loss: 8.4536 - val_mae: 2.0637
# Epoch 89/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3038 - mae: 1.7581 - val_loss: 8.0030 - val_mae: 2.1140
# Epoch 90/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.1515 - mae: 1.7007 - val_loss: 8.1396 - val_mae: 2.0886
# Epoch 91/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.0816 - mae: 1.7144 - val_loss: 8.1178 - val_mae: 2.1525
# Epoch 92/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1231 - mae: 1.7275 - val_loss: 7.9856 - val_mae: 2.0869
# Epoch 93/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.1589 - mae: 1.7122 - val_loss: 8.1988 - val_mae: 2.1670
# Epoch 94/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.1010 - mae: 1.6743 - val_loss: 8.2883 - val_mae: 2.1761
# Epoch 95/100
# 16/16 [==============================] - 0s 4ms/step - loss: 5.8389 - mae: 1.6771 - val_loss: 7.8904 - val_mae: 2.0437
# Epoch 96/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0505 - mae: 1.7077 - val_loss: 8.0352 - val_mae: 2.1347
# Epoch 97/100
# 16/16 [==============================] - 0s 4ms/step - loss: 5.9776 - mae: 1.6851 - val_loss: 8.2653 - val_mae: 2.1506
# Epoch 98/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.0679 - mae: 1.6982 - val_loss: 8.1454 - val_mae: 2.1399
# Epoch 99/100
# 16/16 [==============================] - 0s 4ms/step - loss: 5.8999 - mae: 1.6658 - val_loss: 8.0361 - val_mae: 2.0309
# Epoch 100/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.0787 - mae: 1.6818 - val_loss: 8.2007 - val_mae: 2.1571

# %% [markdown]
# ### 학습과정의 시각화 및 성능 테스트

# %%
hist = pd.DataFrame(history.history)
hist
# Out:
#           loss        mae    val_loss    val_mae
# 0   568.240967  22.631964  554.992310  22.308556
# 1   507.116882  21.260155  488.190369  20.766893
# 2   441.651306  19.687202  410.620483  18.850813
# 3   364.138611  17.670027  321.890137  16.375536
# 4   279.652008  15.194950  231.784348  13.573355
# ..         ...        ...         ...        ...
# 95    6.050487   1.707724    8.035228   2.134742
# 96    5.977557   1.685125    8.265253   2.150613
# 97    6.067878   1.698179    8.145368   2.139873
# 98    5.899867   1.665832    8.036057   2.030875
# 99    6.078681   1.681849    8.200727   2.157128
#
# [100 rows x 4 columns]

# %%
# 학습과정 시각화를 위한 정보 추출
loss = history.history['loss']
val_loss = history.history['val_loss']

mae = history.history['mae']
val_mae = history.history['val_mae']

# %%
# 차트의 x 축을 위한 epoch 정보 생성
epochs = range(1, len(loss)+1)

# %%
# loss 정보 시각화
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')
plt.ylim([0,20])
plt.legend()

plt.show()

# %%
# Mean Absolute Error 정보 시각화
plt.plot(epochs, mae, label='Training mae')
plt.plot(epochs, val_mae, label='Validation mae')
plt.title('Training and validation mae')
plt.xlim([1,100])
plt.ylim([0,5])
plt.legend()

plt.show()

# %%
# 테스트 데이터 셋을 통한 성능 측정
test_loss, test_mae = model.evaluate(x=test_dataset, y=test_labels)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 6.2789 - mae: 1.8831

# %%
# 테스트 데이터 셋의 정답과 모델의 예측값 분석을 위한 모델의 예측값 생성
test_predictions = model.predict(test_dataset).flatten()

# %%
# 테스트 데이터 셋의 정답과 모델의 예측값을 이용한 상관 관계 시각화
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0, 50])
plt.ylim([0,50])
_ = plt.plot([-100, 100], [-100, 100])
